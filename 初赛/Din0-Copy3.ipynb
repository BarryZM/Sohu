# %%
import pandas as pd
import numpy as np

# !pip install deepctr[gpu]

# 导入deepctr
from deepctr.models import DIN,DIEN,BST
from deepctr.feature_column import SparseFeat, VarLenSparseFeat, DenseFeat, get_feature_names
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import * 
import tensorflow as tf

from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler


# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "2"

generate='./data/generate/'
path='./data/rec_data/'
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# 2022-05-15 00:32:08.899897: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
user_seq=pd.read_csv(generate+'user_seq_raw.csv',usecols=['suv','itemId'])
train=pd.read_csv(path+'train-dataset.csv')
test=pd.read_csv(path+'test-dataset.csv')
test.rename(columns={'testSampleId':'sampleId'},inplace=True)
category=pd.read_csv(generate+'category.csv')
category.rename(columns={"id":"itemId"},inplace=True)
train=pd.concat([train,test])
del test
train=pd.concat([train,user_seq])
train=pd.merge(train,category,how='left',on='itemId')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27960/3224266884.py in <module>
# ----> 1 user_seq=pd.read_csv(generate+'user_seq_raw.csv',usecols=['suv','itemId'])
#       2 train=pd.read_csv(path+'train-dataset.csv')
#       3 test=pd.read_csv(path+'test-dataset.csv')
#       4 test.rename(columns={'testSampleId':'sampleId'},inplace=True)
#       5 category=pd.read_csv(generate+'category.csv')
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     579
#     580     with parser:
# --> 581         return parser.read(nrows)
#     582
#     583
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1252             nrows = validate_integer("nrows", nrows)
#    1253             try:
# -> 1254                 index, columns, col_dict = self._engine.read(nrows)
#    1255             except Exception:
#    1256                 self.close()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     223         try:
#     224             if self.low_memory:
# --> 225                 chunks = self._reader.read_low_memory(nrows)
#     226                 # destructive to chunks
#     227                 data = _concatenate_chunks(chunks)
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1427
#    1428
# -> 1429 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1430     """
#    1431     Check if an object is a pandas extension array type.
#
# KeyboardInterrupt:

# %%
# 数据处理sparse、dense
for feat in ['itemId']:
    lbe = LabelEncoder()
    train[feat] = lbe.fit_transform(train[feat])

# train[['itemId']]+=1
# train[['category']]+=1
    
ygq=train.copy()
user_seq=train[train['sampleId'].isna()]
user_seq=user_seq[['suv','itemId','category']]
train=train[train['sampleId'].notna()]

# %%
# 造点统计特征
train['pvid_count'] = train.groupby('pvId')['itemId'].transform('count')
train['pvid_item_nunique'] = train.groupby('pvId')['itemId'].transform('nunique')
train['pvid_suv_nunique'] = train.groupby('pvId')['suv'].transform('nunique')
train['item_count'] = train.groupby('itemId')['itemId'].transform('count')
train['item_suv_nunique'] = train.groupby('pvId')['suv'].transform('nunique')

# %%
# train=train[train['userSeq'].notna()]
del train['userSeq']
del train['logTs']

# %%
hist_click=user_seq[['suv','itemId','category']].groupby(['suv']).agg({list}).reset_index()
his_behavior_df=pd.DataFrame()
his_behavior_df['suv']=hist_click['suv']
his_behavior_df['hist_itemId']=hist_click['itemId']
his_behavior_df['hist_category']=hist_click['category']
del hist_click
del user_seq

# %%
data=pd.merge(train,his_behavior_df,how='left',on='suv')

# %%
tmps=data['hist_itemId'].values.tolist()
for i in range(len(tmps)):
    if not isinstance(tmps[i],list):
        tmps[i]=[0]
data['hist_itemId']=tmps

tmps=data['hist_category'].values.tolist()
for i in range(len(tmps)):
    if not isinstance(tmps[i],list):
        tmps[i]=[0]
data['hist_category']=tmps

# data['length'].fillna(0,inplace=True)

del data['sampleId']

# %%
# 把特征分开
sparse_fea = ['suv', 'pvId','itemId', 'operator','category',
              'browserType', 'deviceType', 'osType', 'province', 'city']

behavior_fea = ['itemId','category']

hist_behavior_fea = ['hist_itemId','hist_category']

dense_fea = ['pvid_count', 'pvid_item_nunique', 'pvid_suv_nunique', 'item_count', 'item_suv_nunique']

# %%
sparse_fea_tmp = ['suv', 'pvId', 'operator',
              'browserType', 'deviceType', 'osType', 'province', 'city']

# 数据处理sparse、dense
for feat in sparse_fea_tmp:
    lbe = LabelEncoder()
    data[feat] = lbe.fit_transform(data[feat])

data[dense_fea] = data[dense_fea].fillna(0, )
mms = MinMaxScaler(feature_range=(0, 1))
data[dense_fea] = mms.fit_transform(data[dense_fea])

# %%
data.to_feather(generate+'DIN_data.feather')
ygq.to_feather(generate+'DIN_data_ygq.feather')

# %% [markdown]
# ============================================================================================================

# %% [markdown]
# ## 上为数据处理，下为输入模型

# %%
import pandas as pd
import numpy as np

# !pip install deepctr[gpu]

# 导入deepctr
from deepctr.models import DIN,DIEN,BST
from deepctr.feature_column import SparseFeat, VarLenSparseFeat, DenseFeat, get_feature_names
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import * 
import tensorflow as tf

from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler


# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"] = "2"

generate='./data/generate/'
path='./data/rec_data/'
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# 2022-05-15 01:10:21.913956: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
# 把特征分开
sparse_fea = ['suv', 'pvId','itemId', 'operator','category',
              'browserType', 'deviceType', 'osType', 'province', 'city']

behavior_fea = ['itemId','category']

hist_behavior_fea = ['hist_itemId','hist_category']

dense_fea = ['pvid_count', 'pvid_item_nunique', 'pvid_suv_nunique', 'item_count', 'item_suv_nunique']

# %%
data=pd.read_feather(generate+'DIN_data.feather')
ygq=pd.read_feather(generate+'DIN_data_ygq.feather')

# %%
emb_dim=32
max_len=32

sparse_feature_columns = [SparseFeat(feat, vocabulary_size=data[feat].nunique() + 1, embedding_dim=emb_dim) for feat in sparse_fea]
dense_feature_columns = [DenseFeat(feat, 1, ) for feat in dense_fea]

var_feature_columns = [VarLenSparseFeat(SparseFeat(feat, vocabulary_size=ygq[feat.split('_')[1]].nunique() + 1,
                        embedding_dim=emb_dim, embedding_name=feat.split('_')[1]), maxlen=max_len) for feat in hist_behavior_fea]

dnn_feature_columns = sparse_feature_columns + dense_feature_columns + var_feature_columns

# %%
train=data[data['label'].notna()]
test=data[data['label'].isna()]
del data
del ygq
test.head(20)
# Out:
#          label    pvId     suv  itemId  operator  browserType  deviceType  \
# 4233804    NaN       5  319111   89718       258           26           0
# 4233805    NaN       5  319111   96837       258           26           0
# 4233806    NaN       5  319111   89845       258           26           0
# 4233807    NaN       5  319111   97642       258           26           0
# 4233808    NaN       5  319111   84056       258           26           0
# 4233809    NaN       5  319111   76837       258           26           0
# 4233810    NaN       5  319111   97231       258           26           0
# 4233811    NaN       5  319111   87005       258           26           0
# 4233812    NaN       5  319111   90927       258           26           0
# 4233813    NaN       5  319111   93330       258           26           0
# 4233814    NaN       5  319111   88570       258           26           0
# 4233815    NaN       5  319111   95392       258           26           0
# 4233816    NaN       5  319111   96424       258           26           0
# 4233817    NaN       5  319111   94142       258           26           0
# 4233818    NaN       5  319111   80726       258           26           0
# 4233819    NaN  153352  153142   96289       255            9           3
# 4233820    NaN  153352  153142   93080       255            9           3
# 4233821    NaN  153352  153142   94672       255            9           3
# 4233822    NaN  153352  153142   99461       255            9           3
# 4233823    NaN  153352  153142   88570       255            9           3
#
#          osType  province  city  category  pvid_count  pvid_item_nunique  \
# 4233804       8        32   186         2    0.041667           0.045016
# 4233805       8        32   186         6    0.041667           0.045016
# 4233806       8        32   186         7    0.041667           0.045016
# 4233807       8        32   186         3    0.041667           0.045016
# 4233808       8        32   186         4    0.041667           0.045016
# 4233809       8        32   186         7    0.041667           0.045016
# 4233810       8        32   186         7    0.041667           0.045016
# 4233811       8        32   186         2    0.041667           0.045016
# 4233812       8        32   186         8    0.041667           0.045016
# 4233813       8        32   186         6    0.041667           0.045016
# 4233814       8        32   186         2    0.041667           0.045016
# 4233815       8        32   186        11    0.041667           0.045016
# 4233816       8        32   186         4    0.041667           0.045016
# 4233817       8        32   186         7    0.041667           0.045016
# 4233818       8        32   186         2    0.041667           0.045016
# 4233819       4         1    11         6    0.041667           0.045016
# 4233820       4         1    11        13    0.041667           0.045016
# 4233821       4         1    11        13    0.041667           0.045016
# 4233822       4         1    11         6    0.041667           0.045016
# 4233823       4         1    11         2    0.041667           0.045016
#
#          pvid_suv_nunique  item_count  item_suv_nunique  \
# 4233804               0.0    0.052617               0.0
# 4233805               0.0    0.353261               0.0
# 4233806               0.0    1.000000               0.0
# 4233807               0.0    0.142227               0.0
# 4233808               0.0    0.593296               0.0
# 4233809               0.0    0.227692               0.0
# 4233810               0.0    0.010952               0.0
# 4233811               0.0    0.133669               0.0
# 4233812               0.0    0.289557               0.0
# 4233813               0.0    0.372753               0.0
# 4233814               0.0    0.625435               0.0
# 4233815               0.0    0.709519               0.0
# 4233816               0.0    0.429344               0.0
# 4233817               0.0    0.155448               0.0
# 4233818               0.0    0.038983               0.0
# 4233819               0.0    0.068700               0.0
# 4233820               0.0    0.003938               0.0
# 4233821               0.0    0.142523               0.0
# 4233822               0.0    0.008405               0.0
# 4233823               0.0    0.625435               0.0
#
#                                                hist_itemId  \
# 4233804                                                [0]
# 4233805                                                [0]
# 4233806                                                [0]
# 4233807                                                [0]
# 4233808                                                [0]
# 4233809                                                [0]
# 4233810                                                [0]
# 4233811                                                [0]
# 4233812                                                [0]
# 4233813                                                [0]
# 4233814                                                [0]
# 4233815                                                [0]
# 4233816                                                [0]
# 4233817                                                [0]
# 4233818                                                [0]
# 4233819  [84422, 92855, 94582, 94913, 82786, 82125, 814...
# 4233820  [84422, 92855, 94582, 94913, 82786, 82125, 814...
# 4233821  [84422, 92855, 94582, 94913, 82786, 82125, 814...
# 4233822  [84422, 92855, 94582, 94913, 82786, 82125, 814...
# 4233823  [84422, 92855, 94582, 94913, 82786, 82125, 814...
#
#                                              hist_category
# 4233804                                                [0]
# 4233805                                                [0]
# 4233806                                                [0]
# 4233807                                                [0]
# 4233808                                                [0]
# 4233809                                                [0]
# 4233810                                                [0]
# 4233811                                                [0]
# 4233812                                                [0]
# 4233813                                                [0]
# 4233814                                                [0]
# 4233815                                                [0]
# 4233816                                                [0]
# 4233817                                                [0]
# 4233818                                                [0]
# 4233819  [6, 13, 9, 13, 6, 13, 6, 6, 6, 2, 9, 7, 4, 8, ...
# 4233820  [6, 13, 9, 13, 6, 13, 6, 6, 6, 2, 9, 7, 4, 8, ...
# 4233821  [6, 13, 9, 13, 6, 13, 6, 6, 6, 2, 9, 7, 4, 8, ...
# 4233822  [6, 13, 9, 13, 6, 13, 6, 6, 6, 2, 9, 7, 4, 8, ...
# 4233823  [6, 13, 9, 13, 6, 13, 6, 6, 6, 2, 9, 7, 4, 8, ...

# %%
x_trn = {}
for name in get_feature_names(dnn_feature_columns):
    if name in hist_behavior_fea:
        # 这是历史行为序列
        his_list = [l for l in train[name]]
        x_trn[name] = pad_sequences(his_list, maxlen=max_len, padding='post')      # 二维数组
    else:
        x_trn[name] = train[name].values

x_tst = {}
for name in get_feature_names(dnn_feature_columns):
    if name in hist_behavior_fea:
        # 这是历史行为序列
        his_list = [l for l in test[name]]
        x_tst[name] = pad_sequences(his_list, maxlen=max_len, padding='post')      # 二维数组
    else:
        x_tst[name] = test[name].values

# %%
y_trn=train['label'].values
y_tst=test['label'].values
# y_val=val['label'].values

# %%
# 建立模型
model = DIN(dnn_feature_columns, behavior_fea)

# 查看模型结构
model.summary()

# 模型编译
model.compile('adam', 'binary_crossentropy',metrics=['binary_crossentropy','accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# suv (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# pvId (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# itemId (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# operator (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# category (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# browserType (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# deviceType (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# osType (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# province (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# city (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# sparse_emb_suv (Embedding)      (None, 1, 32)        11359264    suv[0][0]
# __________________________________________________________________________________________________
# sparse_emb_pvId (Embedding)     (None, 1, 32)        12801024    pvId[0][0]
# __________________________________________________________________________________________________
# sparse_seq_emb_hist_itemId (Emb multiple             3267104     itemId[0][0]
#                                                                  hist_itemId[0][0]
#                                                                  itemId[0][0]
# __________________________________________________________________________________________________
# sparse_emb_operator (Embedding) (None, 1, 32)        15040       operator[0][0]
# __________________________________________________________________________________________________
# sparse_seq_emb_hist_category (E multiple             480         category[0][0]
#                                                                  hist_category[0][0]
#                                                                  category[0][0]
# __________________________________________________________________________________________________
# sparse_emb_browserType (Embeddi (None, 1, 32)        1024        browserType[0][0]
# __________________________________________________________________________________________________
# sparse_emb_deviceType (Embeddin (None, 1, 32)        160         deviceType[0][0]
# __________________________________________________________________________________________________
# sparse_emb_osType (Embedding)   (None, 1, 32)        416         osType[0][0]
# __________________________________________________________________________________________________
# sparse_emb_province (Embedding) (None, 1, 32)        1184        province[0][0]
# __________________________________________________________________________________________________
# sparse_emb_city (Embedding)     (None, 1, 32)        10816       city[0][0]
# __________________________________________________________________________________________________
# hist_itemId (InputLayer)        [(None, 32)]         0
# __________________________________________________________________________________________________
# hist_category (InputLayer)      [(None, 32)]         0
# __________________________________________________________________________________________________
# no_mask (NoMask)                (None, 1, 32)        0           sparse_emb_suv[0][0]
#                                                                  sparse_emb_pvId[0][0]
#                                                                  sparse_seq_emb_hist_itemId[2][0]
#                                                                  sparse_emb_operator[0][0]
#                                                                  sparse_seq_emb_hist_category[2][0
#                                                                  sparse_emb_browserType[0][0]
#                                                                  sparse_emb_deviceType[0][0]
#                                                                  sparse_emb_osType[0][0]
#                                                                  sparse_emb_province[0][0]
#                                                                  sparse_emb_city[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 320)       0           no_mask[0][0]
#                                                                  no_mask[1][0]
#                                                                  no_mask[2][0]
#                                                                  no_mask[3][0]
#                                                                  no_mask[4][0]
#                                                                  no_mask[5][0]
#                                                                  no_mask[6][0]
#                                                                  no_mask[7][0]
#                                                                  no_mask[8][0]
#                                                                  no_mask[9][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 64)        0           sparse_seq_emb_hist_itemId[0][0]
#                                                                  sparse_seq_emb_hist_category[0][0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 64)       0           sparse_seq_emb_hist_itemId[1][0]
#                                                                  sparse_seq_emb_hist_category[1][0
# __________________________________________________________________________________________________
# no_mask_1 (NoMask)              (None, 1, 320)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# attention_sequence_pooling_laye (None, 1, 64)        24201       concatenate_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 384)       0           no_mask_1[0][0]
#                                                                  attention_sequence_pooling_layer[
# __________________________________________________________________________________________________
# pvid_count (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# pvid_item_nunique (InputLayer)  [(None, 1)]          0
# __________________________________________________________________________________________________
# pvid_suv_nunique (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# item_count (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# item_suv_nunique (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# no_mask_3 (NoMask)              (None, 1)            0           pvid_count[0][0]
#                                                                  pvid_item_nunique[0][0]
#                                                                  pvid_suv_nunique[0][0]
#                                                                  item_count[0][0]
#                                                                  item_suv_nunique[0][0]
# __________________________________________________________________________________________________
# no_mask_2 (NoMask)              (None, 384)          0           flatten[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 5)            0           no_mask_3[0][0]
#                                                                  no_mask_3[1][0]
#                                                                  no_mask_3[2][0]
#                                                                  no_mask_3[3][0]
#                                                                  no_mask_3[4][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 384)          0           no_mask_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 5)            0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# no_mask_4 (NoMask)              multiple             0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 389)          0           no_mask_4[0][0]
#                                                                  no_mask_4[1][0]
# __________________________________________________________________________________________________
# dnn_1 (DNN)                     (None, 64)           140992      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            64          dnn_1[0][0]
# __________________________________________________________________________________________________
# prediction_layer (PredictionLay (None, 1)            1           dense[0][0]
# ==================================================================================================
# Total params: 27,621,770
# Trainable params: 27,621,530
# Non-trainable params: 240
# __________________________________________________________________________________________________

# %%
history = model.fit(x_trn, y_trn, verbose=1,epochs=100,validation_split=0.2,batch_size=256)
# Out:
# Train on 3387043 samples, validate on 846761 samples
# 2022-05-15 01:11:11.088105: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-05-15 01:11:11.117180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1666] Found device 0 with properties:
# name: NVIDIA RTX A5000 major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:4f:00.0
# 2022-05-15 01:11:11.117206: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-15 01:11:11.120943: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-15 01:11:11.122708: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-15 01:11:11.122956: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-15 01:11:11.123403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-05-15 01:11:11.124200: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-05-15 01:11:11.124330: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-05-15 01:11:11.124971: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1794] Adding visible gpu devices: 0
# 2022-05-15 01:11:11.126039: I tensorflow/core/platform/cpu_feature_guard.cc:145] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX
# 2022-05-15 01:11:11.150897: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000000000 Hz
# 2022-05-15 01:11:11.159707: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f9076f9b40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-15 01:11:11.159750: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-05-15 01:11:11.160863: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1666] Found device 0 with properties:
# name: NVIDIA RTX A5000 major: 8 minor: 6 memoryClockRate(GHz): 1.695
# pciBusID: 0000:4f:00.0
# 2022-05-15 01:11:11.160922: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-15 01:11:11.160964: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-15 01:11:11.160996: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-05-15 01:11:11.161025: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-05-15 01:11:11.161055: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2022-05-15 01:11:11.161084: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2022-05-15 01:11:11.161114: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-05-15 01:11:11.162574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1794] Adding visible gpu devices: 0
# 2022-05-15 01:11:11.162647: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-05-15 01:11:11.667012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1206] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-05-15 01:11:11.667048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212]      0
# 2022-05-15 01:11:11.667054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1225] 0:   N
# 2022-05-15 01:11:11.669465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1351] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22128 MB memory) -> physical GPU (device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:4f:00.0, compute capability: 8.6)
# 2022-05-15 01:11:11.672384: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55f91accb3b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-05-15 01:11:11.672409: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A5000, Compute Capability 8.6
# Epoch 1/100
# 2022-05-15 01:11:15.148622: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-05-15 01:11:16.260884: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 3386880/3387043 [============================>.] - ETA: 0s - loss: 0.4701 - binary_crossentropy: 0.4602 - acc: 0.8127-
# 2022-05-15 01:16:49.553173: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 0, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2022-05-15 01:16:49.555096: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 1, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2022-05-15 01:16:49.557171: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:568] layout failed: Invalid argument: The graph couldn't be sorted in topological order.
# 2022-05-15 01:16:49.561476: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:568] model_pruner failed: Invalid argument: MutableGraphView::MutableGraphView error: node 'attention_sequence_pooling_layer/local_activation_unit/concat' has self cycle fanin 'attention_sequence_pooling_layer/local_activation_unit/concat'.
# 2022-05-15 01:16:49.571373: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:568] remapper failed: Invalid argument: MutableGraphView::MutableGraphView error: node 'attention_sequence_pooling_layer/local_activation_unit/concat' has self cycle fanin 'attention_sequence_pooling_layer/local_activation_unit/concat'.
# 2022-05-15 01:16:49.572836: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:568] arithmetic_optimizer failed: Invalid argument: The graph couldn't be sorted in topological order.
# 2022-05-15 01:16:49.574214: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 0, topological sort failed with message: The graph couldn't be sorted in topological order.
# 2022-05-15 01:16:49.575517: E tensorflow/core/grappler/optimizers/dependency_optimizer.cc:697] Iteration = 1, topological sort failed with message: The graph couldn't be sorted in topological order.
# 3387043/3387043 [==============================] - 390s 115us/sample - loss: 0.4701 - binary_crossentropy: 0.4602 - acc: 0.8127 - val_loss: 0.4903 - val_binary_crossentropy: 0.4782 - val_acc: 0.8047
# Epoch 2/100
# 3387043/3387043 [==============================] - 383s 113us/sample - loss: 0.4513 - binary_crossentropy: 0.4344 - acc: 0.8220 - val_loss: 0.5191 - val_binary_crossentropy: 0.5030 - val_acc: 0.7960
# Epoch 3/100
# 3387043/3387043 [==============================] - 382s 113us/sample - loss: 0.4400 - binary_crossentropy: 0.4157 - acc: 0.8296 - val_loss: 0.5392 - val_binary_crossentropy: 0.5156 - val_acc: 0.7820
# Epoch 4/100
# 3387043/3387043 [==============================] - 383s 113us/sample - loss: 0.4121 - binary_crossentropy: 0.3794 - acc: 0.8452 - val_loss: 0.5379 - val_binary_crossentropy: 0.5043 - val_acc: 0.7919
# Epoch 5/100
# 3387043/3387043 [==============================] - 382s 113us/sample - loss: 0.3658 - binary_crossentropy: 0.3265 - acc: 0.8683 - val_loss: 0.5364 - val_binary_crossentropy: 0.4946 - val_acc: 0.7971
# Epoch 6/100
# 3387043/3387043 [==============================] - 382s 113us/sample - loss: 0.3174 - binary_crossentropy: 0.2742 - acc: 0.8915 - val_loss: 0.5341 - val_binary_crossentropy: 0.4869 - val_acc: 0.8030
# Epoch 7/100
# 3387043/3387043 [==============================] - 382s 113us/sample - loss: 0.2766 - binary_crossentropy: 0.2319 - acc: 0.9098 - val_loss: 0.5408 - val_binary_crossentropy: 0.4912 - val_acc: 0.8031
# Epoch 8/100
# 3387043/3387043 [==============================] - 382s 113us/sample - loss: 0.2488 - binary_crossentropy: 0.2038 - acc: 0.9213 - val_loss: 0.5503 - val_binary_crossentropy: 0.4995 - val_acc: 0.7984
# Epoch 9/100
# 3387043/3387043 [==============================] - 383s 113us/sample - loss: 0.2311 - binary_crossentropy: 0.1863 - acc: 0.9287 - val_loss: 0.5547 - val_binary_crossentropy: 0.5038 - val_acc: 0.7993
# Epoch 10/100
# 3387043/3387043 [==============================] - 383s 113us/sample - loss: 0.2204 - binary_crossentropy: 0.1758 - acc: 0.9331 - val_loss: 0.5583 - val_binary_crossentropy: 0.5075 - val_acc: 0.7932
# Epoch 11/100
# 2060800/3387043 [=================>............] - ETA: 2:08 - loss: 0.1618 - binary_crossentropy: 0.1186 - acc: 0.9563- ETA: 2:08 - loss: 0.1615 - binary_crossentropy: 0.1183

# %%
# 模型预测
test['rate'] = model.predict(x_tst, verbose=1, batch_size=256)
test[['suv', 'itemId', 'rate']].to_csv('./din_rank_score.csv', index=False)

# %%
ygq=list(test['rate'])

# 生成提交文件
sub_path='./data/submission/'
sub=pd.read_csv(sub_path+'section2.txt', sep='\t')
sub['result'] = ygq
sub.to_csv('./data/section2DIN0.txt', sep='\t', index=False)

# %%
# !nvidia-smi
